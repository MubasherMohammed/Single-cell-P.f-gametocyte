# %%
import scanpy as sc
import pandas as pd
#import loompy 
import numpy as np 
import scvelo as scv
import cellrank as cr
import matplotlib.pyplot as plt
import matplotlib as mpl
from anndata import AnnData
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
scv.set_figure_params(dpi=120)
sc.settings.set_figure_params(dpi=120)
sc.settings.set_figure_params(dpi=150, facecolor='white')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 5
#       3 #import loompy
#       4 import numpy as np
# ----> 5 import scvelo as scv
#       6 import cellrank as cr
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'scvelo'

# %%
ldata_10x = scv.read_loom("./possorted_genome_bam_T88Y5.loom")
ldata_ss2 = scv.read_loom("./gams_smart.loom")

# %%
ldata_ss2.obs_names = [i.replace('/crex/proj/uppstore2019072/10xgams/ss2_data/bam_all/A10_R1.17_532.bam:', '') for i in ldata_ss2.obs_names]
ldata_ss2.obs_names = [i.replace('.bam', '') for i in ldata_ss2.obs_names]

ldata_ss2.obs_names_make_unique()
ldata_ss2.obs_names
# Out:
# Index(['A10_R1.18_360', 'A10_R1.18_361', 'A11_R1.17_532', 'A11_R1.18_360',
#        'A11_R1.18_361', 'A12_R1.17_532', 'A12_R1.18_360', 'A12_R1.18_361',
#        'A13_R1.17_532', 'A13_R1.18_360',
#        ...
#        'P5_R1.18_361', 'P6_R1.17_532', 'P6_R1.18_360', 'P6_R1.18_361',
#        'P7_R1.17_532', 'P7_R1.18_360', 'P8_R1.17_532', 'P8_R1.18_360',
#        'P9_R1.17_532', 'P9_R1.18_360'],
#       dtype='object', length=1085)

# %%
ldata = ldata_ss2.concatenate(ldata_10x)

# %%
ldata.write_loom('./gams_all_looms.loom')

# %%
anndata = sc.read_h5ad('/proj/snic2020-16-146/10xgams/seurat_analysis/results/single_cell/integrated_dataset_SS2_10X.h5ad')

# %%
adata = scv.utils.merge(ldata, anndata)

# %%
#ldata.obs_names = [i.replace('-0', '') for i in ldata.obs_names]
#ldata_ss2.obs_names = [i.replace('.bam', '') for i in ldata_ss2.obs_names]
adata = sc.read_h5ad('/proj/snic2020-16-146/10xgams/seurat_analysis/results/single_cell/integrated_dataset_SS2_10X.h5ad')

# %%
adata.obs['batch'] = [i.replace('0', 'SS2') for i in adata.obs['batch']]
adata.obs['batch'] = [i.replace('1', '10X') for i in adata.obs['batch']]

# %%
adata.uns['batch_colors'] 
adata.uns['batch_colors'] = ['#ff7f0e','#1f77b4']

# %%
adata.write_h5ad('/proj/snic2020-16-146/10xgams/seurat_analysis/results/single_cell/integrated_dataset_SS2_10X_velo.h5ad')
sc.pl.umap(adata, color ='batch')
# Out:
# /home/mubasher/.pyenv/versions/3.9.0/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4991 × 4937
#     obs: 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_counts', 'louvain_0.4', 'leiden_0.4', 'louvain_0.6', 'leiden_0.6', 'louvain_0.8', 'leiden_0.8', 'louvain_0.9', 'leiden_0.9', 'louvain_1.0', 'leiden_1.0', 'louvain_1.1', 'leiden_1.1', 'louvain_1.2', 'leiden_1.2', 'louvain_1.4', 'leiden_1.4', 'louvain_1.6', 'leiden_1.6'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     uns: 'batch_colors', 'clusters_colors', 'day_colors', 'hvg', 'leiden', 'leiden_0.4_colors', 'leiden_0.6_colors', 'leiden_0.8_colors', 'leiden_0.9_colors', 'leiden_1.0_colors', 'leiden_1.1_colors', 'leiden_1.2_colors', 'leiden_1.4_colors', 'leiden_1.6_colors', 'louvain', 'louvain_0.4_colors', 'louvain_0.6_colors', 'louvain_0.8_colors', 'louvain_0.9_colors', 'louvain_1.0_colors', 'louvain_1.1_colors', 'louvain_1.2_colors', 'louvain_1.4_colors', 'louvain_1.6_colors', 'neighbors', 'pca', 'umap', 'wilcoxon'
#     obsm: 'X_pca', 'X_scanorama', 'X_umap'
#     varm: 'PCs'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'
