# %%
import warnings
import scanpy as sc
import anndata as an
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from urllib import request
import scanorama
import os

sc.settings.set_figure_params(dpi=70)
# sc.set_figure_params(facecolor="white", figsize=(8, 8))
sc.logging.print_header()
sc.settings.verbosity = 3
# Out:
# scanpy==1.9.1 anndata==0.8.0 umap==0.5.3 numpy==1.22.4 scipy==1.9.1 pandas==1.4.2 scikit-learn==1.1.2 statsmodels==0.13.2 python-igraph==0.9.9 louvain==0.7.1 pynndescent==0.5.7

# %%
adata = sc.read_10x_h5('../raw_feature_bc_matrix.h5')
adata
# Out:
# reading ../raw_feature_bc_matrix.h5
#  (0:00:07)
# AnnData object with n_obs × n_vars = 6794880 × 5358
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
# mitochondrial genes
adata.var['mt'] = adata.var_names.str.startswith('MT-') 
# ribosomal genes
adata.var['ribo'] = adata.var_names.str.startswith(("RPS","RPL"))
# hemoglobin genes.
adata.var['hb'] = adata.var_names.str.contains(("^HB[^(P)]"))

adata.var
# Out:
#                     gene_ids    feature_types  \
# PF3D7_1400200  PF3D7_1400200  Gene Expression
# PF3D7_1400300  PF3D7_1400300  Gene Expression
# PF3D7_1400400  PF3D7_1400400  Gene Expression
# PF3D7_1400500  PF3D7_1400500  Gene Expression
# PF3D7_1400600  PF3D7_1400600  Gene Expression
# ...                      ...              ...
# PF3D7_0115200  PF3D7_0115200  Gene Expression
# PF3D7_0115300  PF3D7_0115300  Gene Expression
# PF3D7_0115400  PF3D7_0115400  Gene Expression
# PF3D7_0115600  PF3D7_0115600  Gene Expression
# PF3D7_0115700  PF3D7_0115700  Gene Expression
#
#                                           genome     mt   ribo     hb
# PF3D7_1400200  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_1400300  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_1400400  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_1400500  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_1400600  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# ...                                          ...    ...    ...    ...
# PF3D7_0115200  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_0115300  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_0115400  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_0115600  Plasmodium_falciparum.ASM276v2_MM  False  False  False
# PF3D7_0115700  Plasmodium_falciparum.ASM276v2_MM  False  False  False
#
# [5358 rows x 6 columns]

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt','ribo','hb'], percent_top=None, log1p=False, inplace=True)

# %%
mito_genes = adata.var_names.str.startswith('MT-')

# for each cell compute fraction of counts in mito genes vs. all genes
# the `.A1` is only necessary as X is sparse (to transform to a dense array after summing)
adata.obs['percent_mt2'] = np.sum(
    adata[:, mito_genes].X, axis=1).A1 / np.sum(adata.X, axis=1).A1

# add the total counts per cell as observations-annotation to adata
adata.obs['n_counts'] = adata.X.sum(axis=1).A1

adata
# Out:
# /scratch/29796830/ipykernel_8247/168008836.py:5: RuntimeWarning: invalid value encountered in true_divide
#   adata.obs['percent_mt2'] = np.sum(
# AnnData object with n_obs × n_vars = 6794880 × 5358
#     obs: 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'pct_counts_hb', 'percent_mt2', 'n_counts'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
variables = ['n_genes_by_counts', 'total_counts']
sc.pl.violin(adata, keys=variables, jitter=0.4, rotation= 45, multi_panel=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

print(adata.n_obs, adata.n_vars)
# Out:
# filtered out 6790325 cells that have less than 200 genes expressed
# filtered out 339 genes that are detected in less than 3 cells
# 4555 5019

# %%
# save normalized counts in raw slot.
adata.raw = adata

# normalize to depth 10000 UMIs per cell
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)

# logaritmize
sc.pp.log1p(adata)
# Out:
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
# Create folder
os.makedirs('./results/supplementary_files', exist_ok=True)

# %%
# Load gene list from file
cell_cycle_genes = [x.strip() for x in open('./cc_genesMMS.txt')]

# Split into 2 lists
s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]

# Filter out genes not detectd in our dataset 
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]

# %%
sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)
# Out:
# calculating cell cycle phase
# computing score 'S_score'
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     681 total control genes are used. (0:00:00)
# computing score 'G2M_score'
# WARNING: genes are not in var_names and ignored: ['PF3D7_1027700', 'PF3D7_1027700', '']
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     953 total control genes are used. (0:00:00)
# -->     'phase', cell cycle phase (adata.obs)
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_score_genes.py:151: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   for cut in np.unique(obs_cut.loc[gene_list]):

# %%
sc.pl.violin(adata, ['S_score', 'G2M_score'], jitter=0.4, rotation=45)

# %%
sc.pp.highly_variable_genes(
    adata, n_top_genes=4000,
    inplace=True)
print("Highly variable genes: %d"%sum(adata.var.highly_variable))
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# Highly variable genes: 4000

# %%
#plot variable genes
sc.pl.highly_variable_genes(adata)

# subset for variable genes in the dataset
#adata = adata[:, adata.var['highly_variable']]

# %%
# adata = adata.copy()     #run this line if you get the "AttributeError: swapaxes not found" 

# regress out unwanted variables
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])

# scale data, clip values exceeding standard deviation 10.
sc.pp.scale(adata, max_value=10)
# Out:
# regressing out ['total_counts', 'pct_counts_mt']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:25)

# %%
adata.var.highly_variable
# Out:
# PF3D7_1401000     True
# PF3D7_1401100     True
# PF3D7_1401200     True
# PF3D7_1401300    False
# PF3D7_1401400     True
#                  ...
# PF3D7_0114500    False
# PF3D7_0115000     True
# PF3D7_0115100     True
# PF3D7_0115600    False
# PF3D7_0115700     True
# Name: highly_variable, Length: 5019, dtype: bool

# %%
sc.tl.pca(
    data = adata, 
    svd_solver = 'arpack',
    n_comps = 50,
    use_highly_variable = True)
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:05)

# %%
sc.pl.pca(adata, components = ['1,2','3,4','5,6','7,8'], ncols=2)

# %%
sc.pp.neighbors(adata, n_pcs = 10, n_neighbors = 20)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 10
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)

# %%
sc.tl.umap(adata,min_dist=0.3,spread=0.5,maxiter=150)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:05)

# %%
sc.pl.umap(adata)

# %%
resolutions = [0.4,0.6,0.8,0.9,1.0,1.1,1.2,1.4,1.6]

# %%
for i in resolutions:
    sc.tl.louvain( adata, resolution = i, key_added = "louvain_"+str(i) )
    sc.tl.leiden(  adata, resolution = i, key_added = "leiden_"+str(i) )
# Out:
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 8 clusters and added
#     'louvain_0.4', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 10 clusters and added
#     'leiden_0.4', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 10 clusters and added
#     'louvain_0.6', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 11 clusters and added
#     'leiden_0.6', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 10 clusters and added
#     'louvain_0.8', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 13 clusters and added
#     'leiden_0.8', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 10 clusters and added
#     'louvain_0.9', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 13 clusters and added
#     'leiden_0.9', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 11 clusters and added
#     'louvain_1.0', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 15 clusters and added
#     'leiden_1.0', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 13 clusters and added
#     'louvain_1.1', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 16 clusters and added
#     'leiden_1.1', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 14 clusters and added
#     'louvain_1.2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 18 clusters and added
#     'leiden_1.2', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 15 clusters and added
#     'louvain_1.4', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden_1.4', the cluster labels (adata.obs, categorical) (0:00:00)
# running Louvain clustering
#     using the "louvain" package of Traag (2017)
#     finished: found 17 clusters and added
#     'louvain_1.6', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 21 clusters and added
#     'leiden_1.6', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
all_clusterings = [ ('louvain_'+str(i)) for i in resolutions] + [ ('leiden_'+str(i)) for i in resolutions ]

# %%
sc.pl.umap(adata = adata, color=all_clusterings , ncols=3 )

# %%
os.makedirs('./results/single_cell', exist_ok=True)
adata.write_h5ad('./results/single_cell/single_cell_10X.h5ad')

# %%
sc.tl.rank_genes_groups(
    adata = adata, 
    groupby = 'louvain_1.0', 
    method = 'wilcoxon', 
    use_raw = False, 
    key_added = "wilcoxon",n_genes=100)
# Out:
# ranking genes
#     finished: added to `.uns['wilcoxon']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:09)
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /home/mubasher/.conda/envs/spatial/lib/python3.9/site-packages/scanpy/tools/_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
sc.pl.rank_genes_groups(
    adata = adata, 
    groupby = 'louvain_1.0', 
    n_genes=10, 
    sharey=False, 
    key="wilcoxon",)
